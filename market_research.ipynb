# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv('data.csv')

# %%
ax = data_frame.plot(x='question_tag',y='number_agree',kind='bar')
plt.title('Binderhub Workshop\nMarket Research');
plt.ylabel('Number Responses')
# Out:
# Text(0, 0.5, 'Number Responses')
